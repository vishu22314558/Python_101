# %% [markdown]
# ![image.png](attachment:c2efe05c-d39b-46e6-b0e0-190ea262775f.png)

# %%
2 == 2
# Out:
# True

# %%
'bye' == 'bye'
# Out:
# True

# %%
'Bye' == 'bye'
# Out:
# False

# %%
3 != 2
# Out:
# True

# %%
1 >1
# Out:
# False

# %%
2 < 3
# Out:
# True

# %%
1 >=1
# Out:
# True

# %% [markdown]
# ![image.png](attachment:2460584a-a48c-4168-a965-e3ce349eebc6.png)

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2  and 1 < 3
# Out:
# True

# %%
 ('h' == 'd') and ( True )
# Out:
# False

# %%
 ('h' == 'd') or ( True )
# Out:
# True

# %%
 ('h' == 'd') or ( 0 > 1 )
# Out:
# False

# %%
 ('h' == 'd') or ( 0 > 1 )
# Out:
# False

# %%
not (1 == 1)
# Out:
# False

# %%
not (1 < 0)
# Out:
# True

# %%
12 !=12
# Out:
# False
