# %% [markdown]
# ![image.png](attachment:0ed93f0f-3f4c-4755-9187-89017c433836.png)

# %%
0.1+0.2 - 0.3
# Out:
# 5.551115123125783e-17

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %%
my_d = 2
my_d = ["dog1" ,"dog2"]
print(my_d)
# Out:
# ['dog1', 'dog2']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=5

# %%
a
# Out:
# 5

# %%
a=10
a
# Out:
# 10

# %%
a =a+a
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
type(4.1)
# Out:
# float

# %%
my_income = 100

tax_rate = 0.1

my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'hello'
# Out:
# 'hello'

# %%
"World"
# Out:
# 'World'

# %%
 " I ' am going to run"
# Out:
# " I ' am going to run"

# %%
print("Hello")
print("Hello")
# Out:
# Hello
# Hello

# %%
print("Hello  \n Test")
# Out:
# Hello
#  Test

# %%
len("Hello test")
# Out:
# 10

# %%
mystring = "Hello World"
print(mystring)
mystring[0]
# Out:
# Hello World
# 'r'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring1 = "abcdefghijk"
print(mystring1)
# Out:
# abcdefghijk

# %%
mystring1[2:]
# Out:
# 'cdefghijk'

# %%
mystring1[:3]
# Out:
# 'abc'

# %%
mystring1[:3]
# Out:
# 'def'

# %%
mystring1[1:3]
# Out:
# 'bc'

# %%
mystring1[::2]
# Out:
# 'acegik'

# %%
mystring1[::-1]
# Out:
# 'kjihgfedcba'

# %%
name = "Sam"

# Strings are Immutable

# %%
name[0]='P'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4501820df49a> in <module>
# ----> 1 name[0]='P'
#
# TypeError: 'str' object does not support item assignment

# %%
name[1:]
# Out:
# 'am'

# %%
last_le = 'P' +name[1:]

# %%
last_le
# Out:
# 'Pam'

# %%
x = "Hello " * 5

# %%
x
# Out:
# 'Hello Hello Hello Hello Hello '

# %%
2+5
# Out:
# 7

# %%
'2'+'5'
# Out:
# '25'

# %% [markdown]
# int('2')+int('5')

# %%
x.upper()
# Out:
# 'HELLO HELLO HELLO HELLO HELLO '

# %%
x = x.upper()

# %%
x
# Out:
# 'HELLO HELLO HELLO HELLO HELLO '

# %%
x.split()
# create list
# Out:
# ['HELLO', 'HELLO', 'HELLO', 'HELLO', 'HELLO']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
R = 100/777

# %%
R
# Out:
# 0.1287001287001287

# %%
print("This is the value for R = {r} ".format(r=R))
# Out:
# This is the value for R = 0.1287001287001287

# %%
print("This is the value for R = {r:1.3f} ".format(r=R))
# Out:
# This is the value for R = 0.129

# %%
print("This is the value for R = {r:10.3f} ".format(r=R))
# Out:
# This is the value for R =      0.129

# %%
name = 'test'
age = 10
Sal = 10.232566

# %%
print(f'this is the {name}')
# Out:
# this is the test

# %%
print(f'this is the {name}  age {age}  Sal {Sal:2.2f}')
# Out:
# this is the test  age 10  Sal 10.23

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_list = [1,2,"test"]

# %%
my_list
# Out:
# [1, 2, 'test']

# %%
len(my_list)
# Out:
# 3

# %%
my_list[:]
# Out:
# [1, 2, 'test']

# %%
my_list[::-1]
# Out:
# ['test', 2, 1]

# %%
my_list[:len(my_list)]
# Out:
# [1, 2, 'test']

# %%
my_list[-1]
# Out:
# 'test'

# %%
my_list_1 = [2,3,4]

# %%
my_list + my_list_1
# Out:
# [1, 2, 'test', 2, 3, 4]

# %%
new_list = my_list + my_list_1

# %%
new_list
# Out:
# [1, 2, 'test', 2, 3, 4]

# %%
new_list[0] = 'ONE'

# %%
new_list
# Out:
# ['ONE', 2, 'test', 2, 3, 4]

# %%
new_list.append('5')

# %%
new_list
# Out:
# ['ONE', 2, 'test', 2, 3, 4, '5']

# %%
new_list.reverse()

# %%
new_list
# Out:
# ['5', 4, 3, 2, 'test', 2, 'ONE']

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 'ONE'

# %%
new_list.remove(new_list[0])

# %%
new_list
# Out:
# [4, 3, 2, 'test', 2]

# %%
new_list_2 = [3,5,6,8,2,9]

# %%
# sort is inplace chnage and does not return any list 

new_list_2.sort()

# %%
new_list_2
# Out:
# [2, 3, 5, 6, 8, 9]

# %%
S_l = new_list_2.sort()

# %%
#empty list 
S_l

# %%
type(S_l)
# Out:
# NoneType

# %%
S_l = new_list_2

# %%
S_l
# Out:
# [2, 3, 5, 6, 8, 9]

# %% [markdown]
# ![image.png](attachment:af58f6e7-8db1-4f2b-a081-8a8988c69956.png)

# %% [markdown]
# ![image.png](attachment:019b8e5f-1f84-4efe-8796-4b78cf3e3149.png)

# %% [markdown]
# ![image.png](attachment:7901bd58-f1df-4f2b-b306-8d61b5f09fb3.png)

# %%
my_dict = {'key1':'value1' , 'key2':'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
d = {'k1':1 , 'k2' : [0,1,0] , 'k3' : {'insidek3':100}}

# %%
d['k2']
# Out:
# [0, 0, 0]

# %%
d['k3']
# Out:
# {'insidek3': 100}

# %%
d['k3']['insidek3']
# Out:
# 100

# %%
d['k2'][:-1]
# Out:
# [0, 1]

# %%
d1 = {'k1':['a','b']}

# %%
d1['k1'][1].upper()
# Out:
# 'B'

# %%
d1['k1'] = 3000

# %%
d1['k2'] = 200

# %%
d1
# Out:
# {'k1': 3000, 'k2': 200}

# %%
d1.values()
# Out:
# dict_values([3000, 200])

# %%
d1.keys()
# Out:
# dict_keys(['k1', 'k2'])

# %%
d1.items()
# Out:
# dict_items([('k1', 3000), ('k2', 200)])

# %%
t1 = d1.items()

# %%
t1
# Out:
# dict_items([('k1', 3000), ('k2', 200)])

# %% [markdown]
# ![image.png](attachment:9e08f700-9eb6-40e5-9420-b4e33d1c77db.png)

# %%
t = (1,2,3)

# %%
t[0]
# Out:
# 1

# %%
t2 = (1,'one',2)

# %%
t2
# Out:
# (1, 'one', 2)

# %%
t2.count(1)
# Out:
# 1

# %%
t2.count(2)
# Out:
# 1

# %%
t2.index(1)
# Out:
# 0

# %% [markdown]
# ### Text Files

# %%
# %%writefile myfile.txt
# Hello this is a text file
# this is the second file
# this is the third file
# Out:
# Overwriting myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile = open('myfile111.txt')
# Out:
# ----------------------------------------------------------------
# FileNotFoundError              Traceback (most recent call last)
# <ipython-input-3-832f7a20907c> in <module>
# ----> 1 myfile = open('myfile111.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile111.txt'

# %%
pwd
# Out:
# '/Users/vishvajeetsingh/Project/Python/Git_Code/Python_101/Basic_Py_Notebook'

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is a text file \nthis is the second file \nthis is the third file\n'

# %%
myfile.read()

# becuse of curser
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
cont = myfile.read()

# %%
cont
# Out:
# 'Hello this is a text file \nthis is the second file \nthis is the third file\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readline()
# Out:
# 'Hello this is a text file \n'

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file \n',
#  'this is the second file \n',
#  'this is the third file\n']

# %%
myfile.seek(0)
# Out:
# 0

# %%
cont = myfile.read()

# %%
l = cont.split('\n')

# %%
l
# Out:
# ['Hello this is a text file ',
#  'this is the second file ',
#  'this is the third file',
#  '']

# %% [markdown]
# ![image.png](attachment:8335af37-43bc-481f-b185-ed8e2f530ec4.png)

# %%
myfile.close()

# %%
# new way 
# no need to worry about closing the file session 

with open("myfile.txt") as my_new_file:
    con = my_new_file.read()

# %%
con
# Out:
# ''

# %%
#shift Tab to get function definition 

with open("myfile.txt",mode='w') as my_new_file:
    con = my_new_file.read()
# Out:
# ----------------------------------------------------------------
# UnsupportedOperation           Traceback (most recent call last)
# <ipython-input-30-4b777efe5840> in <module>
#       2
#       3 with open("myfile.txt",mode='w') as my_new_file:
# ----> 4     con = my_new_file.read()
#       5
#       6
#
# UnsupportedOperation: not readable

# %% [markdown]
# ![image.png](attachment:8a41b655-ce3c-4f40-920b-9ad22cea2bcd.png)

# %%
#shift Tab to get function definition 

with open("myfile.txt",mode='r') as my_new_file:
    con = my_new_file.read()
    print(con)
# Out:
# Hello this is a text file
# this is the second file
# this is the third file

# %%
type(con)
# Out:
# str

# %%
con
# Out:
# 'Hello this is a text file \nthis is the second file \nthis is the third file\n'

# %%
with open("myfile.txt",mode='a') as my_new_file:
    my_new_file.write("\nThis is the fourth line")

# %%
#shift Tab to get function definition 

with open("myfile.txt",mode='r') as my_new_file:
    con = my_new_file.read()
    print(con)
# Out:
# Hello this is a text file
# this is the second file
# this is the third file
# This is the fourth line

# %%
# w mode will create the new file
with open("hhhhh.txt" , mode='w') as f:
    f.write("Hello from W")
